# %% [markdown]
# # Math ideas to learn
# - angle between vectors using dot
# - vector cross product
# - matrix determinate
# - eigenvalues
# - linear systems (simultaneous equations of x unknowns)

# %% [markdown]
# ## Exercises

# %%
# Timing test for matrix multiplication with/without numpy
# Show how the performance varies with different sizes
