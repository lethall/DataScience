# %% [markdown]
# ###Bar Graphs
# example:

# %%
from matplotlib import pyplot as plt

movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

plt.bar(range(len(movies)), num_oscars)

plt.title("Series Of Movies")
plt.ylabel("Number of Academy Awards")

plt.xticks(range(len(movies)), movies)

plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[27], line 11
#       8 plt.title("Series Of Movies")
#       9 plt.ylabel("Number of Academy Awards")
# ---> 11 plt.xticks(movies, movies)
#      13 plt.show
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\pyplot.py:2060, in xticks(ticks, labels, minor, **kwargs)
#    2057         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2058                         "without setting 'ticks'")
#    2059 else:
# -> 2060     locs = ax.set_xticks(ticks, minor=minor)
#    2062 labels_out: list[Text] = []
#    2063 if labels is None:
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\axis.py:2138, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2133     first_key = next(iter(kwargs))
#    2134     raise ValueError(
#    2135         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2136         "other than 'minor' modify the text labels and can only be used if "
#    2137         "'labels' are passed as well.")
# -> 2138 result = self._set_tick_locations(ticks, minor=minor)
#    2139 if labels is not None:
#    2140     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\axis.py:2077, in Axis._set_tick_locations(self, ticks, minor)
#    2073 def _set_tick_locations(self, ticks, *, minor=False):
#    2074     # see docstring of set_ticks
#    2075
#    2076     # XXX if the user changes units, the information will be lost here
# -> 2077     ticks = self.convert_units(ticks)
#    2078     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2079     if len(ticks):
#
# File d:\Zeken\Projects\venvs\ipythontools\lib\site-packages\matplotlib\axis.py:1771, in Axis.convert_units(self, x)
#    1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
# -> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1772                                  f'units: {x!r}') from e
#    1773 return ret
#
# ConversionError: Failed to convert value(s) to axis units: ['Annie Hall', 'Ben-Hur', 'Casablanca', 'Gandhi', 'West Side Story']

# %%
from collections import Counter
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

plt.bar([x + 5 for x in histogram.keys()], histogram.values(), 10, edgecolor=(0,0,0))

plt.axis([-5, 105, 0, 5])

plt.title("Distribution of Exam grades")
plt.xticks([10 * i for i in range(11)])
plt.xlabel("Decile")
plt.ylabel("Number of Students")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# It is imporant to note how this is visually constructed, with the scores between each decile marked together - "Counter(min(grade // 10 * 10, 90) for grade in grades)

# %% [markdown]
# Sometimes charts can be deceptive, for example:

# %%
mentions = [500, 505]
years = [2017, 2018]
plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("Sales")
plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 499, 506])
plt.title("Sales since I started working")
plt.show()
