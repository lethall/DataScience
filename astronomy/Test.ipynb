# %%
from ipycanvas import Canvas
c = Canvas(width=100, height=100)
c.stroke_style = "green"
c.stroke_line(10,10,80,80)
c
# Out:
# Canvas(height=100, width=100)

# %%
from ipycanvas import Canvas

canvas = Canvas(width=200, height=200)

canvas.fill_rect(25, 25, 100, 100)
canvas.clear_rect(45, 45, 60, 60)
canvas.stroke_style = "red"
canvas.stroke_rect(50, 50, 50, 50)

canvas
# Out:
# Canvas(height=200, width=200)

# %%
from PIL import Image
from io import BytesIO
import sqlite3
from IPython.display import display

def get(id,db):
	return db.execute("select d from im where id = ?", (id,)).fetchone()[0]

def im(id,db):
	d = get(id, db)
	return Image.open(BytesIO(d))

def yr(yy):
	return ['%d%02d' % (yy,m) for m in range(1,13)]

fv = [9712,9511,8903,8406,8207,8112,7102,7009,7001,6906,6703,7406,6203,8310]
#db=sqlite3.connect("")

# %%
#display(im(
